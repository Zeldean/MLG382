# %% [markdown]
# <b><font size="6">|032|ANN|Vehicle Price Prediction</font></b>
#
# * **Author**: Dino Giovannoni
# * **Date:**: 20-April-2025
#
# Based on dataset: https://www.kaggle.com/datasets/nehalbirla/vehicle-dataset-from-cardekho/data
# Notebook based on:
#  - https://www.kaggle.com/code/farzadnekouei/polynomial-regression-regularization-assumptions
#  - https://www.kaggle.com/code/mohaiminul101/car-price-prediction

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# # Load the Data

# %%
df = pd.read_csv(r"./../../data/car_data.csv")

# %% [markdown]
# ## Inspect the first 5 rows

# %%
display(df.head())
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %% [markdown]
# ## Inspect information about the dataframe

# %% [markdown]
# Provide a list of the DataFrame columns and the data types in each of the columns.

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB
# None

# %% [markdown]
# # Data Processing & Exploratory Data Analysis

# %% [markdown]
# ## View the Descriptive Statistics

# %% [markdown]
# Extract various descriptive statistics from the dataset, including the mean/standard deviation, mmin, max, etc.

# %%
display(df.describe().T)
# Out:
#                count          mean           std      min      25%      50%  \
# Year           301.0   2013.627907      2.891554  2003.00   2012.0   2014.0
# Selling_Price  301.0      4.661296      5.082812     0.10      0.9      3.6
# Present_Price  301.0      7.628472      8.644115     0.32      1.2      6.4
# Kms_Driven     301.0  36947.205980  38886.883882   500.00  15000.0  32000.0
# Owner          301.0      0.043189      0.247915     0.00      0.0      0.0
#
#                    75%       max
# Year            2016.0    2018.0
# Selling_Price      6.0      35.0
# Present_Price      9.9      92.6
# Kms_Driven     48767.0  500000.0
# Owner              0.0       3.0

# %% [markdown]
# ## Feature Transformation - Year

# %% [markdown]
# "Year" shows the car model year. We can replace this column with the cars age attribute.To calculate the age, we consider the origin time to be 1 year older than the maximum model year:

# %%
maxYear = df["Year"].max() + 1
df = df.assign(Age = lambda df_: maxYear - df_["Year"])
df.drop('Year', axis=1, inplace=True)
display(df.describe().T)
# Out:
#                count          mean           std     min      25%      50%  \
# Selling_Price  301.0      4.661296      5.082812    0.10      0.9      3.6
# Present_Price  301.0      7.628472      8.644115    0.32      1.2      6.4
# Kms_Driven     301.0  36947.205980  38886.883882  500.00  15000.0  32000.0
# Owner          301.0      0.043189      0.247915    0.00      0.0      0.0
# Age            301.0      5.372093      2.891554    1.00      3.0      5.0
#
#                    75%       max
# Selling_Price      6.0      35.0
# Present_Price      9.9      92.6
# Kms_Driven     48767.0  500000.0
# Owner              0.0       3.0
# Age                7.0      16.0

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Since Car_Name contains 98 unique categories, and this number of categories is very high compared to the number of dataset samples, it is better to drop it:

# %%
df.drop('Car_Name', axis=1, inplace=True)

# %% [markdown]
# We can determine which are the numerical and categorical features:

# %%
output_var = 'Selling_Price'
numeric_data = df.select_dtypes(include=['number']).columns.tolist()
numeric_features = [col for col in numeric_data if col != output_var]
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()

print(f'Numeric Features    : {numeric_features}')
print(f'Categorical Features: {categorical_features}')
# Out:
# Numeric Features    : ['Present_Price', 'Kms_Driven', 'Owner', 'Age']
# Categorical Features: ['Fuel_Type', 'Seller_Type', 'Transmission']

# %% [markdown]
# ## Histograms of Numerical Raw Features

# %%
plt.figure(figsize=(12, 10))
for i, col in enumerate(numeric_features):
    plt.subplot(2, 2, i+1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.histplot(df[output_var], kde=True)
plt.title(output_var)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Transformation of Skewed Data

# %% [markdown]
# All the numeric data seems to be right-skewed. Let's confirm this by looking at the skewness coefficient for all the numerical columns:

# %%
for col in numeric_data:
    print(f'{col} = {df[col].skew()}')
# Out:
# Selling_Price = 2.493422417797524
# Present_Price = 4.083150156592918
# Kms_Driven = 6.436012679752193
# Owner = 7.616849679389442
# Age = 1.2461891109537502

# %% [markdown]
# For all the columns, the skewness coefficient is greater that 1, so they are all highly skewed. Since the Owner contains 0 values, we need a transformation that can deal with zero-values. We could use a log1p transformation, but lets use the Yeo-Johnson transformer.

# %%
pt = PowerTransformer(method='yeo-johnson')
print(numeric_data)
df_transformed = df.copy()
df_transformed[numeric_data] = pt.fit_transform(df[numeric_data])
# Out:
# ['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'Age']

# %% [markdown]
# ### Statistics of Transformed Data

# %%
display(df_transformed.describe().T)
# Out:
#                count          mean       std       min       25%       50%  \
# Selling_Price  301.0  1.888486e-16  1.001665 -1.690727 -0.957921  0.169748
# Present_Price  301.0  1.416364e-16  1.001665 -1.640607 -1.090967  0.244612
# Kms_Driven     301.0  1.829470e-16  1.001665 -2.679837 -0.638029  0.141104
# Owner          301.0 -1.770455e-17  1.001665 -0.194759 -0.194759 -0.194759
# Age            301.0  5.901518e-18  1.001665 -2.856946 -0.879888  0.127786
#
#                     75%       max
# Selling_Price  0.681225  2.538367
# Present_Price  0.680200  3.182202
# Kms_Driven     0.650039  4.822699
# Owner         -0.194759  5.134553
# Age            0.783425  2.294062

# %% [markdown]
# ### Histograms of Transformed Numeric Features

# %%
plt.figure(figsize=(12, 10))
for i, col in enumerate(df_transformed[numeric_data].columns):
    plt.subplot(3, 2, i+1)
    sns.histplot(df_transformed[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box Plots of Transformed Numeric Features

# %%
# fig, ax = plt.subplots(figsize=(10, 6))
# boxplot = df_transformed[numeric_features].boxplot(vert = 1, ax=ax)  
# _ = ax.set_title(f'Box Plot: Transformed Data')

# plt.figure(figsize=(18,12))
sns.boxplot(data=df_transformed[numeric_features], orient='h')
plt.show()

# %% [markdown]
# ## Scaling of all numeric data

# %%
import joblib
joblib.dump(pt, 'powerTrans.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(iso, 'isoForest.pkl')
model.save(r"ANN-mod-car.keras")


# Example: new raw data (before encoding or scaling)
new_data = pd.DataFrame([{
    'Year': 2017,
    'Present_Price': 8.5,
    'Kms_Driven': 30000,
    'Fuel_Type': 'Petrol',
    'Seller_Type': 'Dealer',
    'Transmission': 'Manual',
    'Owner': 0,
    'Selling_Price': 0
}])

new_data['Age'] = maxYear - new_data['Year']
new_data.drop(columns='Year', inplace=True)

df_transformed = new_data.copy()
df_transformed[numeric_data] = pt.transform(new_data[numeric_data])

new_scaled = df_transformed.copy()
new_scaled[numeric_data] = scaler.transform(df_transformed[numeric_data])

new_encoded = pd.get_dummies(data=new_scaled, columns=categorical_features, drop_first=True)


# 🧩 Reindex to match training data columns exactly
# new_encoded = new_encoded.reindex(columns=X_train.columns, fill_value=0)


prediction = model.predict(new_scaled)



print("Predicted Selling Price:", prediction[0][0])
# Out:
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[594], line 36
#
#      29 new_encoded = pd.get_dummies(data=new_scaled, columns=categorical_features, drop_first=True)
#
#      32 # 🧩 Reindex to match training data columns exactly
#
#      33 # new_encoded = new_encoded.reindex(columns=X_train.columns, fill_value=0)
#
# ---> 36 prediction = model.predict(new_scaled)
#
#      40 print("Predicted Selling Price:", prediction[0][0])
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
#     120     # To get the full stack trace, call:
#
#     121     # `keras.config.disable_traceback_filtering()`
#
# --> 122     raise e.with_traceback(filtered_tb) from None
#
#     123 finally:
#
#     124     del filtered_tb
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/optree/ops.py:766, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#
#     764 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#
#     765 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
#
# --> 766 return treespec.unflatten(map(func, *flat_args))
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#
#    6637     results = [
#
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#
#    6639     ]
#
#    6641 else:
#
#    6642     # else, only a single dtype is given
#
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#
#    6645     return res.__finalize__(self, method="astype")
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#
#     427 elif using_copy_on_write():
#
#     428     copy = False
#
# --> 430 return self.apply(
#
#     431     "astype",
#
#     432     dtype=dtype,
#
#     433     copy=copy,
#
#     434     errors=errors,
#
#     435     using_cow=using_copy_on_write(),
#
#     436 )
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/internals/managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#
#     361         applied = b.apply(f, **kwargs)
#
#     362     else:
#
# --> 363         applied = getattr(b, f)(**kwargs)
#
#     364     result_blocks = extend_blocks(applied, result_blocks)
#
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/internals/blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#
#     755         raise ValueError("Can not squeeze with more than one column.")
#
#     756     values = values[0, :]  # type: ignore[call-overload]
#
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#
#     760 new_values = maybe_coerce_values(new_values)
#
#     762 refs = None
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#
#     234     dtype = dtype.numpy_dtype
#
#     236 try:
#
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#
#     238 except (ValueError, TypeError):
#
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#
#     240     #  trying to convert to float
#
#     241     if errors == "ignore":
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#
#     179     values = values.astype(dtype, copy=copy)
#
#     181 else:
#
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
#
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:133, in _astype_nansafe(arr, dtype, copy, skipna)
#
#     129     raise ValueError(msg)
#
#     131 if copy or arr.dtype == object or dtype == object:
#
#     132     # Explicit copy, or required since NumPy can't view from / to object.
#
# --> 133     return arr.astype(dtype, copy=True)
#
#     135 return arr.astype(dtype, copy=copy)
#
#
#
# ValueError: could not convert string to float: 'Petrol'

# %% [markdown]
# While not strictly necessary, let's scale the transformed data to be in the range 0-2. For this we use the MinMaxScler.

# %%
display(df_transformed[numeric_data].head())
scaler = MinMaxScaler(feature_range=(0, 2))
scaler.fit(df_transformed[numeric_data])

df_transformed[numeric_data] = scaler.transform(df_transformed[numeric_data])
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner       Age
# 0       0.847112       0.728084    0.701586    0.0  1.158892
# 1       1.009288       0.946691    0.845480    0.0  1.297567
# 2       1.214467       0.960274    0.371942    0.0  0.465054
# 3       0.775139       0.614405    0.317768    0.0  1.512530
# 4       0.994060       0.810390    0.841246    0.0  1.158892

# %% [markdown]
# ### Histograms of Transformed & Scaled Numeric Features

# %%
plt.figure(figsize=(12, 10))
for i, col in enumerate(df_transformed[numeric_data].columns):
    plt.subplot(3, 2, i+1)
    sns.histplot(df_transformed[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorical Data

# %%
print(f'Categorical Features: {categorical_features}')
# Out:
# Categorical Features: ['Fuel_Type', 'Seller_Type', 'Transmission']

# %%
display(df.describe().T)
# Out:
#                count          mean           std     min      25%      50%  \
# Selling_Price  301.0      4.661296      5.082812    0.10      0.9      3.6
# Present_Price  301.0      7.628472      8.644115    0.32      1.2      6.4
# Kms_Driven     301.0  36947.205980  38886.883882  500.00  15000.0  32000.0
# Owner          301.0      0.043189      0.247915    0.00      0.0      0.0
# Age            301.0      5.372093      2.891554    1.00      3.0      5.0
#
#                    75%       max
# Selling_Price      6.0      35.0
# Present_Price      9.9      92.6
# Kms_Driven     48767.0  500000.0
# Owner              0.0       3.0
# Age                7.0      16.0

# %% [markdown]
# ### Frequency Distributions

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(15,5), dpi=100)
colors = ['#0055ff', '#ff7000', '#23bf00']
CustomPalette = sns.set_palette(sns.color_palette(colors))
       
for i in range(len(categorical_features)):
    graph = sns.countplot(x=categorical_features[i], data=df_transformed, ax=ax[i])
    ax[i].set_xlabel(categorical_features[i], fontsize=15)
    ax[i].set_ylabel('Count', fontsize=12)
    ax[i].set_ylim([0,300])
    ax[i].tick_params(axis='x', labelsize=12)
    for cont in graph.containers:
        graph.bar_label(cont)

plt.suptitle('Frequency Distribution of Categorical Variables', fontsize=20) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Categorical Variables Encoding

# %% [markdown]
# We implement dummy encoding on categorical columns, since they are all nominal variables:

# %%
df_transformed = pd.get_dummies(data=df_transformed, columns=categorical_features, drop_first=True)
df_transformed.sample(5)
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner       Age  \
# 88        0.860441       0.759325    0.875144    0.0  1.297567
# 114       0.423112       0.280020    0.575692    0.0  0.987845
# 62        1.689659       1.544328    1.058656    0.0  1.158892
# 66        1.715687       1.339379    0.471010    0.0  0.465054
# 107       0.451102       0.285461    0.544298    0.0  1.297567
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 88              False              True                   False
# 114             False              True                    True
# 62               True             False                   False
# 66              False              True                   False
# 107             False              True                    True
#
#      Transmission_Manual
# 88                  True
# 114                 True
# 62                 False
# 66                 False
# 107                 True

# %% [markdown]
# ## Outlier Detection and removal

# %%
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Selling_Price           301 non-null    float64
#  1   Present_Price           301 non-null    float64
#  2   Kms_Driven              301 non-null    float64
#  3   Owner                   301 non-null    float64
#  4   Age                     301 non-null    float64
#  5   Fuel_Type_Diesel        301 non-null    bool
#  6   Fuel_Type_Petrol        301 non-null    bool
#  7   Seller_Type_Individual  301 non-null    bool
#  8   Transmission_Manual     301 non-null    bool
# dtypes: bool(4), float64(5)
# memory usage: 13.1 KB

# %%
iso = IsolationForest(contamination=0.01, random_state=42)
outliers = iso.fit_predict(df_transformed)
display(df_transformed[outliers == -1].head())
df_cleaned = df_transformed[outliers == 1]
display(df_cleaned.info())
# Out:
#     Selling_Price  Present_Price  Kms_Driven  Owner       Age  \
# 53       1.610092       1.468752    1.288475    0.0  1.297567
# 64       1.971013       1.547854    0.344648    0.0  0.465054
# 85       0.718529       1.350748    1.311453    2.0  1.859292
#
#     Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 53              True             False                    True
# 64              True             False                   False
# 85             False              True                    True
#
#     Transmission_Manual
# 53                False
# 64                False
# 85                False
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Selling_Price           298 non-null    float64
#  1   Present_Price           298 non-null    float64
#  2   Kms_Driven              298 non-null    float64
#  3   Owner                   298 non-null    float64
#  4   Age                     298 non-null    float64
#  5   Fuel_Type_Diesel        298 non-null    bool
#  6   Fuel_Type_Petrol        298 non-null    bool
#  7   Seller_Type_Individual  298 non-null    bool
#  8   Transmission_Manual     298 non-null    bool
# dtypes: bool(4), float64(5)
# memory usage: 15.1 KB
# None

# %% [markdown]
# ### Box Plots of Transformed Numeric Features

# %%
# fig, ax = plt.subplots(figsize=(10, 6))
# boxplot = df_cleaned[numeric_features].boxplot(vert = 0, ax=ax)  
# _ = ax.set_title(f'Box Plot: Cleaned Data')

plt.figure(figsize=(10,6))
sns.boxplot(data=df_cleaned[numeric_features], orient='h')
plt.show()

# %% [markdown]
# ## Create Scatter Plots of Data

# %%
sns.pairplot(
    data = df_cleaned[numeric_data],
    corner = True,
    kind='reg',
    plot_kws={
        'line_kws': {'color': 'red'},
        'scatter_kws': {'alpha': 0.5}
    }
)

# %%
# x_name = 'Disney movies released'
# y_name = 'Divorce rates in the United Kingdom'

# ax = df.plot.scatter(x=x_name, y=y_name, c='blue', s=10)

# %% [markdown]
# ## Calculate the correlation coeffients

# %%
def CorrPlot(df, dropDuplicates = True, figsize = (8, 6)):
    # df = df.corr()
    df = np.abs(df.corr())
    # Exclude duplicate correlations by masking upper right values
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=bool)
        mask[np.triu_indices_from(mask)] = True
    # Set background color / chart style
    sns.set_style(style = 'white')
    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=figsize)
    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)
    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                    annot=True,
                    square=True,
                    linewidth=.5, cbar_kws={"shrink": .75}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                annot=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)

CorrPlot(df_cleaned, figsize = (12, 10))

# %% [markdown]
# ### Feature Selection - Correlations

# %% [markdown]
# We see that the lowest correlation coefficient is with Owner. Let's remove it.

# %%
df_cleaned = df_cleaned.drop('Owner', axis=1)

# %% [markdown]
# # Neural Network Model

# %% [markdown]
# ## Extract features & define input and output variables

# %%
features = df_cleaned.columns.drop(output_var).to_list()
X = df_cleaned[features]
y = df_cleaned[output_var]
display(X, y)
# Out:
#      Present_Price  Kms_Driven       Age  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0         0.728084    0.701586  1.158892             False              True
# 1         0.946691    0.845480  1.297567              True             False
# 2         0.960274    0.371942  0.465054             False              True
# 3         0.614405    0.317768  1.512530             False              True
# 4         0.810390    0.841246  1.158892              True             False
# ..             ...         ...       ...               ...               ...
# 296       1.030511    0.770454  0.767639              True             False
# 297       0.749361    0.960419  0.987845             False              True
# 298       1.007563    1.105958  1.674763             False              True
# 299       1.063012    0.426820  0.465054              True             False
# 300       0.749361    0.326951  0.767639             False              True
#
#      Seller_Type_Individual  Transmission_Manual
# 0                     False                 True
# 1                     False                 True
# 2                     False                 True
# 3                     False                 True
# 4                     False                 True
# ..                      ...                  ...
# 296                   False                 True
# 297                   False                 True
# 298                   False                 True
# 299                   False                 True
# 300                   False                 True
#
# [298 rows x 7 columns]
# 0      0.847112
# 1      1.009288
# 2      1.214467
# 3      0.775139
# 4      0.994060
#          ...
# 296    1.348665
# 297    0.928451
# 298    0.847112
# 299    1.444284
# 300    1.061698
# Name: Selling_Price, Length: 298, dtype: float64

# %% [markdown]
# ## Split data into training and test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=90)

# %% [markdown]
# ## ANN Model

# %%
model = Sequential()
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1)) # O/P

model.compile(optimizer='rmsprop', loss='mse')

history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.3746 - val_loss: 0.3256
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2026 - val_loss: 0.2280
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1249 - val_loss: 0.1670
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1098 - val_loss: 0.1511
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0946 - val_loss: 0.1302
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0883 - val_loss: 0.1128
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0784 - val_loss: 0.0953
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0685 - val_loss: 0.0829
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0666 - val_loss: 0.0742
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0529 - val_loss: 0.0679
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0494 - val_loss: 0.0602
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0480 - val_loss: 0.0555
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0340 - val_loss: 0.0415
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0266 - val_loss: 0.0333
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0268 - val_loss: 0.0345
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0190 - val_loss: 0.0385
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0198 - val_loss: 0.0236
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0162 - val_loss: 0.0209
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0135 - val_loss: 0.0190
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - val_loss: 0.0167
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0094 - val_loss: 0.0147
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100 - val_loss: 0.0143
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0074 - val_loss: 0.0099
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0092
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - val_loss: 0.0095
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072 - val_loss: 0.0084
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068 - val_loss: 0.0090
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0065 - val_loss: 0.0121
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069 - val_loss: 0.0073
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057 - val_loss: 0.0077
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0061 - val_loss: 0.0064
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0063
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0062
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0064 - val_loss: 0.0088
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - val_loss: 0.0063
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058 - val_loss: 0.0067
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - val_loss: 0.0078
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - val_loss: 0.0090
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060 - val_loss: 0.0060
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - val_loss: 0.0097
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - val_loss: 0.0079
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - val_loss: 0.0066
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0071
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - val_loss: 0.0055
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - val_loss: 0.0074
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - val_loss: 0.0063
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - val_loss: 0.0065
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - val_loss: 0.0063
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0048 - val_loss: 0.0054
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - val_loss: 0.0092
# Epoch 64/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051 - val_loss: 0.0060
# Epoch 65/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 66/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 67/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 68/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0063
# Epoch 69/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 70/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - val_loss: 0.0053
# Epoch 71/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 72/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 73/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0046 - val_loss: 0.0050
# Epoch 74/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 75/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0051
# Epoch 76/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 77/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0036 - val_loss: 0.0051
# Epoch 78/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040 - val_loss: 0.0070
# Epoch 79/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 80/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - val_loss: 0.0066
# Epoch 81/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 82/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 83/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 0.0066
# Epoch 84/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045 - val_loss: 0.0071
# Epoch 85/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0054 - val_loss: 0.0049
# Epoch 86/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0042 - val_loss: 0.0050
# Epoch 87/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0040 - val_loss: 0.0054
# Epoch 88/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042 - val_loss: 0.0049
# Epoch 89/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0048
# Epoch 90/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 91/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 92/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - val_loss: 0.0048
# Epoch 93/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039 - val_loss: 0.0061
# Epoch 94/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041 - val_loss: 0.0055
# Epoch 95/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - val_loss: 0.0050
# Epoch 96/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - val_loss: 0.0055
# Epoch 97/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041 - val_loss: 0.0053
# Epoch 98/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0044 - val_loss: 0.0051
# Epoch 99/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 100/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038 - val_loss: 0.0051

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title("Loss Over Epochs")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.show()

# %%
import joblib
joblib.dump(pt, 'powerTrans.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(iso, 'isoForest.pkl')
model.save(r"ANN-mod-car.keras")


# Example: new raw data (before encoding or scaling)
new_data = pd.DataFrame([{
    'Year': 2017,
    'Present_Price': 8.5,
    'Kms_Driven': 30000,
    'Fuel_Type': 'Petrol',
    'Seller_Type': 'Dealer',
    'Transmission': 'Manual',
    'Owner': 0,
    'Selling_Price': 0
}])

new_data['Age'] = maxYear - new_data['Year']
new_data.drop(columns='Year', inplace=True)

df_transformed = new_data.copy()
df_transformed[numeric_data] = pt.transform(new_data[numeric_data])

new_scaled = df_transformed.copy()
new_scaled[numeric_data] = scaler.transform(df_transformed[numeric_data])

new_encoded = pd.get_dummies(data=new_scaled, columns=categorical_features, drop_first=True)


# 🧩 Reindex to match training data columns exactly
# new_encoded = new_encoded.reindex(columns=X_train.columns, fill_value=0)


prediction = model.predict(new_encoded)



print("Predicted Selling Price:", prediction[0][0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[595], line 36
#      29 new_encoded = pd.get_dummies(data=new_scaled, columns=categorical_features, drop_first=True)
#      32 # 🧩 Reindex to match training data columns exactly
#      33 # new_encoded = new_encoded.reindex(columns=X_train.columns, fill_value=0)
# ---> 36 prediction = model.predict(new_encoded)
#      40 print("Predicted Selling Price:", prediction[0][0])
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/Second-Brain/{20} Bachelor of Computing/3 Year/MLG382/Code/.venv/lib/python3.11/site-packages/keras/src/layers/input_spec.py:227, in assert_input_compatibility(input_spec, inputs, layer_name)
#     222     for axis, value in spec.axes.items():
#     223         if value is not None and shape[axis] not in {
#     224             value,
#     225             None,
#     226         }:
# --> 227             raise ValueError(
#     228                 f'Input {input_index} of layer "{layer_name}" is '
#     229                 f"incompatible with the layer: expected axis {axis} "
#     230                 f"of input shape to have value {value}, "
#     231                 "but received input with "
#     232                 f"shape {shape}"
#     233             )
#     234 # Check shape.
#     235 if spec.shape is not None:
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Input 0 of layer "dense_42" is incompatible with the layer: expected axis -1 of input shape to have value 7, but received input with shape (1, 5)
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=(1, 5), dtype=float32)
#   • training=False
#   • mask=None

# %% [markdown]
# ## Perform Predictions

# %%
y_train_pred = model.predict(X_train)
y_test_pred  = model.predict(X_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# # Model Evaluation

# %%
plt.scatter(y_train, y_train_pred, s=10)
plt.plot([0, 2], [0,2], color = 'red', linestyle='dashed')

plt.xlabel('Actual Output (km/l)')
plt.ylabel('Predicted Output (km/l)')
plt.axis('equal')
plt.title('Training Data')
plt.tight_layout()

# %%
plt.scatter(y_test, y_test_pred, s=10)
plt.plot([0, 2], [0,2], color = 'red', linestyle='dashed')
plt.xlabel('Actual Output (km/l)')
plt.ylabel('Predicted Output (km/l)')
plt.axis('equal')
plt.title('Test Data')
plt.tight_layout()

# %% [markdown]
# ## Calculating the metrics

# %%
train_mae =  np.round(mean_absolute_error(y_train, y_train_pred),3 )
train_mse =  np.round(mean_squared_error(y_train, y_train_pred),3)
train_rmse = np.round(np.sqrt(train_mse),3)

print('COMPARISON OF METRICS - TRAINING DATA')
print(f'Training MAE   : {train_mae}')
print(f'Training MSE   : {train_mse}')
print(f'Training RMSE  : {train_rmse}')
# Out:
# COMPARISON OF METRICS - TRAINING DATA
# Training MAE   : 0.053
# Training MSE   : 0.004
# Training RMSE  : 0.063

# %%
test_mae =  np.round(mean_absolute_error(y_test, y_test_pred),3) 
test_mse =  np.round(mean_squared_error(y_test, y_test_pred),3)
test_rmse = np.round(np.sqrt(test_mse),3)

print('COMPARISON OF METRICS - TEST DATA')
print(f'Testing MAE   : {test_mae}')
print(f'Testing MSE   : {test_mse}')
print(f'Testing RMSE  : {test_rmse}')
# Out:
# COMPARISON OF METRICS - TEST DATA
# Testing MAE   : 0.052
# Testing MSE   : 0.005
# Testing RMSE  : 0.071
